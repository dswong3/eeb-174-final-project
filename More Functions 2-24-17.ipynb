# %%
#goal is to have input of a time period and output of ALL species in that time period

import csv
file = open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/new.feliformia.csv")
readCSV = csv.reader(file, delimiter=',')


def Feliformia (TimePeriod):
    i = 0
    identifier = None
    for row in readCSV:
        if( i < 18 ):
            i += 1
            continue
        if( len(row) < 12 ):
            continue
        if (row[12] == TimePeriod):
            identifier = row[5]
            print (identifier + " lived in the " + TimePeriod)


Feliformia("Middle Pleistocene")
# Out:
# Lynx sp. lived in the Middle Pleistocene
# Panthera pardus lived in the Middle Pleistocene
# Panthera tigris lived in the Middle Pleistocene
# Crocuta crocuta lived in the Middle Pleistocene
# Paguma larvata lived in the Middle Pleistocene
# Herpestes cf. urva lived in the Middle Pleistocene
# Viverra cf. zibetha lived in the Middle Pleistocene
# Crocuta crocuta lived in the Middle Pleistocene
# Panthera pardus lived in the Middle Pleistocene
# Herpestes sanguineus lived in the Middle Pleistocene
# Crocuta crocuta lived in the Middle Pleistocene
# Panthera leo lived in the Middle Pleistocene
# Panthera pardus lived in the Middle Pleistocene
# Felis libyca lived in the Middle Pleistocene
# Felidae indet. lived in the Middle Pleistocene
# Felis caracal lived in the Middle Pleistocene
# Ichneumia albicauda lived in the Middle Pleistocene
# Panthera leo lived in the Middle Pleistocene
# Hyaena hyaena lived in the Middle Pleistocene
# Ichneumia albicauda lived in the Middle Pleistocene
# ...

# %%
#goal is to add to previous code and create a list of corresponding time periods 
#and display how many elements are in that time period (display that looks cleaner)

import csv
file = open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/feliformia.csv")
readCSV = csv.reader(file, delimiter=',')

ListOfTimePeriods = []

def Feliformia (TimePeriod):
    i = 0
    identifier = None
    for row in readCSV:
        if( i < 18 ):
            i += 1
            continue
        if( len(row) < 12 ):
            continue
        if (row[12] == TimePeriod):
            identifier = row[5]
            ListOfTimePeriods.append(identifier)
            continue


Feliformia("Turolian")

str1 = ' , '.join(ListOfTimePeriods)
print ("This Time Period includes " + str(len(ListOfTimePeriods)) + str(" species, which are: ") + str1)
# Out:
# This Time Period includes 83 species, which are: Ictitherium gaudryi , Viverrinae indet. , Machairodus fires , Metailurus sp. , Machairodus ex gr. gigantheus , Ictitherium sp. , Ictitherium cf. sinence , Adcrocuta eximia , Hyaenictitherium hyaenoides , Machairodus kurteni , Hyaena sp. , Felidae indet. , Ictitherium sp. , Felis christoli , Dinofelis sp. , Amphimachairodus giganteus , Paramachairodus ? maximiliani , Thalassictis aff. hyaenoides , Metailurus parvulus , Machairodus giganteus , Adcrocuta eximia , Thalassictis adroveri , Plioviverrops guerini , Lycyaena sp. , Viverra sp. , Ictitherium sp. , Felis sp. , Ictitherium hipparionum , Adcrocuta eximia , Machairodus sp. , Ictitherium hipparionum , Adcrocuta eximia , Metailurus major , Machairodus sp. , Ictitherium hipparionum , Hyaenictis eximia , Paradoxurinae indet. , Viverridae ? indet. , Ictitherium gaudryi , Viverrinae indet. , Ictitherium gaudryi , Epimachairodus fires , Pseudaelurus sp. , Viverra sp. , Paradoxurinae indet. 
# ...

# %%
def Feliformia():
    FeliformiaCSV= open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/feliformia.csv", "r", encoding = "ISO-8859-1")
    alldata=FeliformiaCSV.readlines() [19:]
    Timeperiod_dict = {}
    for line in alldata:
        #line = line.replace('\"', '')
        record_elements = line.split(",")
        if len(record_elements) < 12:
            continue
        Timeperiod = record_elements[12]
        if Timeperiod in Timeperiod_dict:
            count = Timeperiod_dict[Timeperiod]
            Timeperiod_dict[Timeperiod] = count + 1
        else: 
            Timeperiod_dict[Timeperiod] = 1            
    return Timeperiod_dict

print (Feliformia())
# Out:
# {'Middle Eocene': 1, 'Early Barstovian': 4, 'Late Oligocene': 5, 'Piacenzian': 87, 'Late Pliocene': 57, 'Harrisonian': 4, 'Chadronian': 29, 'MN 1': 2, 'Messinian': 40, 'MP 26': 1, 'Late Hemphillian': 29, 'Burdigalian': 10, 'Ensenadan': 6, 'Late Pleistocene': 239, 'Zanclean': 68, 'MP 24': 1, 'Serravallian': 11, 'Monroecreekian': 1, 'Duchesnean': 1, 'MN 10': 3, 'Middle Miocene': 5, 'MP 30': 3, 'Pleistocene': 337, 'Late Clarendonian': 4, 'Geringian': 14, 'Late Eocene': 10, 'Tortonian': 73, 'Langhian': 15, 'Turolian': 82, 'MN 11': 6, 'Oligocene': 1, 'Early Pliocene': 2, 'Villanyian': 33, 'Hemingfordian': 13, 'Neogene': 4, 'Baodean': 1, 'Orellan': 40, 'Torrejonian': 1, 'Rancholabrean': 15, 'MP 28': 5, 'Early Pleistocene': 170, 'Astaracian': 6, 'MN 12': 9, 'MN 7 + 8': 2, 'Early Oligocene': 24, 'Blancan': 142, 'Hemphillian': 46, 'Middle Pleistocene': 184, 'MN 14': 3, 'Vallesian': 9, 'Chattian': 4, 'Barstovian': 21, 'Miocene': 32, 'Irvingtonian': 116, 'MN 17': 32, 'MP 22': 14, 'MN 6': 8, 'La
# ...

# %% [markdown]
# # All Lines below are work in progress (can ignore)

# %%
FeliformiaCSV= open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/new.feliformia.csv", "r", encoding = "ISO-8859-1")
alldata=FeliformiaCSV.readlines() [19:]
for line in alldata:
    elements = line.split (",")
print(alldata)
# Out:
# ['\n', '"","idreso","family"\n', '\n', '"","timerule","major"\n', '\n', '"","taxon_status","all"\n', '\n', '"Elapsed Time","0.127"\n', '\n', '"Records Found","2780"\n', '\n', '"Records Returned","2780"\n', '\n', '"Records:"\n', '\n', '"occurrence_no","record_type","reid_no","flags","collection_no","identified_name","identified_rank","identified_no","difference","accepted_name","accepted_rank","accepted_no","early_interval","late_interval","max_ma","min_ma","reference_no"\n', '\n', '"138743","occ","","","11798","Ictitherium gaudryi","species","41026","species not entered","Ictitherium","genus","41026","Turolian","","8.7","5.333","11437"\n', '\n', '"138744","occ","","","11798","Viverrinae indet.","subfamily","72213","","Viverrinae","subfamily","72213","Turolian","","8.7","5.333","11437"\n', '\n', '"138826","occ","","","11799","Machaerodus sp.","genus","47826","misspelling of, subjective synonym of","Drepanodon","genus","45918","Late Miocene","Early Pliocene","11.608","3.6","4198"\n', '
# ...

# %%
FeliformiaCSV= open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/new.feliformia.csv") #"r", encoding = "ISO-8859-1")
#read lines that come after 19
alldata=FeliformiaCSV.readlines() [19:]

#create function
def Feliformia(AllTimePeriod):
    for line in alldata:
        elements = line.split(",")
    print (elements)
    #FeliformiaCSV = open(filename, "r", encoding = "ISO-8859-1")

# %%
### STARTING HERE
FeliformiaCSV= open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/new.feliformia.csv", "r", encoding = "ISO-8859-1")
alldata=FeliformiaCSV.readlines() [19:]
for line in alldata:
    line = line.replace('\"', '')
    #elements = line.split (",")
#create function
def Feliformia(AllTimePeriod):
    FeliformiaCSV = open(filename, "r", encoding = "ISO-8859-1")
    #feliformia_records = rTimeperiod.readlines()[19:]
    
    Timeperiod_dict = {}
    for line in alldata:
        
        record_elements = line.split(",")
        Timeperiod = record_elements[12]
        if Timperiod_dict.has_key(Timeperiod)
            
        #Timeperiod_dict[Timeperiod] = # of species #assign of 
    return Timeperiod_dict

# %%
FeliformiaCSV= open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/new.feliformia.csv", "r", encoding = "ISO-8859-1")
alldata=FeliformiaCSV.readlines() [19:]
for line in alldata:
    line = line.replace('\"', '')
    elements = line.split (",")
print (elements)
# Out:
# ['\n']

# %%
import csv
file = open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/new.feliformia.csv")
readCSV = csv.reader(file, delimiter=',')

AllTimePeriods = []

def Feliformia (TimePeriod):
    i = 0
    identifier = None
    for row in readCSV:
        if( i < 18 ):
            i += 1
            continue
        if( len(row) < 12 ):
            continue
        if (row[12] == TimePeriod):
            identifier = row[12]
            AllTimePeriods.append(identifier)
            continue

str1 = ' , '.join(AllOfTimePeriods)
print (str1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9ee8eccae7ca> in <module>()
#      18             AllTimePeriods.append(identifier)
#      19             continue
# ---> 20 str1 = ' , '.join(AllOfTimePeriods)
#      21 print (str1)
#
# NameError: name 'AllOfTimePeriods' is not defined

# %%
import csv
file = open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/new.feliformia.csv")
readCSV = csv.reader(file, delimiter=',')

def Feliformia (TimePeriods):
    feliformia_dict = {}
    feliformia_dict.sort() | uniq
    TimePeriodList = open('filename', "r", enconding = "ISO-8559-1")
    feliformia_data = TimePeriodList.readlines()[19:]
    row[13]

feliformia_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-4f80c76f08a7> in <module>()
#      10     row[13]
#      11
# ---> 12 feliformia_dict
#
# NameError: name 'feliformia_dict' is not defined

# %%
#goal is to add to previous code and create a list of corresponding time periods 
#and display how many elements are in that time period

import csv
file = open("/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/new.feliformia.csv")
readCSV = csv.reader(file, delimiter=',')

result = input("Type time period: ")

ListOfTimePeriods = []

def Feliformia (TimePeriod):
    i = 0
    identifier = None
    for row in readCSV:
        if( i < 18 ):
            i += 1
            continue
        if( len(row) < 12 ):
            continue
        if (row[12] == TimePeriod):
            identifier = row[5]
            ListOfTimePeriods.append(identifier)
            continue

Feliformia(result)


#str1 = ' , '.join(ListOfTimePeriods)
#print (Feliformia(result)) 
#str(len(ListOfTimePeriods)) + str(" species, which are: ") + str1)
# Out:
# Type time period: Turolian
